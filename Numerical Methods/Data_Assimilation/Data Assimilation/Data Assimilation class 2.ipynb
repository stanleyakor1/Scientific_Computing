# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([0.2,0.64,0.9216,0.2890])

# %%
x=np.array([0.2,0.64,0.9216,0.2890])
e=np.random.normal(0,0.9,4)
y=x[1:3]+e[1:3]

# %%
y
# Out:
# array([1.97225562, 1.95899657])

# %%
plt.plot(y,'b*',markersize=4)
plt.show()

# %%
def CF(a):
    x2=np.linspace(-0.1,1.1,100)
    y=np.array([0.63800979, 0.92065716])
    n=len(x2)
    J=np.zeros(n)
    for i in range(0,n):
        J[i]=(x2[i]-0.63800979)**2+(4*x2[i]*(1-x2[i])-0.92065716)**2
    return x2,J

# %%
x2=np.linspace(-0.1,1.1,100)
J=(x2-0.63800979)**2+(4*x2*(1-x2)-0.92065716)**2

# %%
x21=np.linspace(-0.1,1.1,100)
y2=-0.3766286
y3=-0.0950286
J1=(x2-y2)**2+(4*x2*(1-x2)-y3)**2

# %%
plt.plot(x2,J)
plt.plot(x21,J1)
plt.show()

# %%
a=1
j,t=CF(a)
plt.plot(j,t)

# %%
x2=np.array([-0.1,1.1])
y=np.array([0.63800979, 0.92065716])
J=(x2-y)**2+(4*x2*(1-x2)-y)**2
