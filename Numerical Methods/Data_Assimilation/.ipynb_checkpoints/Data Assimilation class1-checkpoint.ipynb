# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dt=1*10**(21)

# %%
S=1372
delta=5.67*10**(-8)
cp=1.05*10**(23)
alpha=0.3
e=0.61

# %%
A=(dt/cp)*(S*(1-alpha))
B=(dt/cp)*4*e*delta

# %%
A
# Out:
# 9.146666666666667

# %%
B
# Out:
# 1.3175999999999999e-09

# %%
def Zero(alpha,e):
    t=np.zeros(1001)
    T=np.zeros(1001)
    for i in range(0, len(t)-1):
        t[i+1]=i*dt
        T[i+1]=T[i]+ (dt/cp)*(S*(1-alpha))-(dt/cp)*4*e*delta*(T[i])**(4)
    return t,T

# %%
alpha=0.3
e=0.61
t,T=Zero(alpha,e)

# %%
plt.plot(t,T)
plt.title("Zero Energy Balance Model")
plt.ylabel("Temp(K)")
plt.xlabel("t(sec)")
plt.show()

# %%
plt.plot(t[0:10],T[0:10])
plt.title("Zero Energy Balance Model")
plt.ylabel("Temp(K)")
plt.xlabel("t(sec)")
plt.show()

# %%
T_mean=np.mean(T)
T_anom=T-T_mean

# %%
plt.plot(t,T_anom)
plt.title("Zero Energy Balance Model")
plt.ylabel("Temp(K)")
plt.xlabel("t(sec)")
plt.show()

# %%
plt.plot(t[0:10],T_anom[0:10])
plt.title("Zero Energy Balance Model")
plt.ylabel("Temp(K)")
plt.xlabel("t(sec)")
plt.show()
